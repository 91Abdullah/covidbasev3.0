# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import pandas as pd
import re
import multiprocessing
from gensim.models import Word2Vec

# %%
def preprocess_apply(row):
    disease = row.disease
    gene = row.gene
    text = row.abstract

    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if w == 'no' or w == 'not' or not w in stop_words]
    porter = PorterStemmer()
    stems = []
    for t in tokens:
        if t == disease:
            stems.append(t)
        elif t == gene:
            stems.append(t)
        else:
            try:
                stems.append(porter.stem(t.lower()))
            except:
                pass
    return stems

# %%
gene_disease_abstract_map = pd.read_csv('gene_disease_abstract_map.csv')

# %%
gene_disease_abstract_map['gene'] = gene_disease_abstract_map['gene'].str.strip()
gene_disease_abstract_map['disease'] = gene_disease_abstract_map['disease'].str.strip()

# %%
gene_disease_abstract_map = gene_disease_abstract_map[gene_disease_abstract_map.disease != 'disease']

# %%
gene_disease_abstract_map['stems'] = gene_disease_abstract_map.apply(preprocess_apply, axis=1)
# Out:
# /tmp/ipykernel_3267854/2524698560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gene_disease_abstract_map['stems'] = gene_disease_abstract_map.apply(preprocess_apply, axis=1)

# %%
gene_disease_abstract_map
# Out:
#                                                  title  \
# 0    Common Variants in CDKN2B-AS1 Associated with ...
# 1    The lncRNA Malat1 functions as a ceRNA to cont...
# 2    No evidence for sylvatic cycles of chikungunya...
# 3    Clinical implications and nomogram prediction ...
# 4    Droplet Digital PCR Analysis of Liquid Biopsy ...
# ..                                                 ...
# 405  Transcriptomic Analysis Reveals Host miRNAs Co...
# 406  Transcriptomic Analysis Reveals Host miRNAs Co...
# 409  miRNA-200c-3p is crucial in acute respiratory ...
# 410  miRNA-200c-3p is crucial in acute respiratory ...
# 411  miRNA-200c-3p is crucial in acute respiratory ...
#
#                                doi  \
# 0     10.1371/journal.pone.0033389
# 1        10.1038/s41401-019-0284-y
# 2       10.1186/s13071-020-04419-1
# 3      10.1097/md.0000000000022806
# 4           10.3390/biology9110379
# ..                             ...
# 405  10.3390/microorganisms9030665
# 406  10.3390/microorganisms9030665
# 409       10.1038/celldisc.2017.21
# 410       10.1038/celldisc.2017.21
# 411       10.1038/celldisc.2017.21
#
#                                               abstract  metaId  \
# 0    BACKGROUND: To date, only a small portion of t...     783
# 1    Long non-coding RNAs (lncRNAs) have been ident...   12926
# 2    BACKGROUND: Dengue, chikungunya and Zika virus...   13550
# 3    Colorectal cancer, especially colon adenocarci...   13556
# 4    SIMPLE SUMMARY: Despite the availability of sc...   14242
# ..                                                 ...     ...
# 405  Ebola virus is a continuing threat to human po...  764184
# 406  Ebola virus is a continuing threat to human po...  764184
# 409  Influenza infection and pneumonia are known to...  764237
# 410  Influenza infection and pneumonia are known to...  764237
# 411  Influenza infection and pneumonia are known to...  764237
#
#                 gene         disease  \
# 0         CDKN2B-AS1        glaucoma
# 1        miR-181c-5p  adenocarcinoma
# 2               PRNT     chikungunya
# 3              FRGCA  adenocarcinoma
# 4     hsa-miR-375-3p          cancer
# ..               ...             ...
# 405   hsa-miR-122-5p     lymphopenia
# 406  hsa-miR-125b-5p     lymphopenia
# 409      miR-200c-3p       influenza
# 410      miR-200c-3p        syndrome
# 411      miR-200c-3p       pneumonia
#
#                                                  stems
# 0    [background, :, to, date, ,, small, portion, g...
# 1    [long, non-cod, rna, (, lncrna, ), identifi, e...
# 2    [background, :, dengu, ,, chikungunya, zika, v...
# 3    [colorect, cancer, ,, especi, colon, adenocarc...
# 4    [simpl, summari, :, despit, avail, screen, pro...
# ..                                                 ...
# 405  [ebola, viru, continu, threat, human, popul, ,...
# 406  [ebola, viru, continu, threat, human, popul, ,...
# 409  [influenza, infect, pneumonia, known, caus, mu...
# 410  [influenza, infect, pneumonia, known, caus, mu...
# 411  [influenza, infect, pneumonia, known, caus, mu...
#
# [322 rows x 7 columns]

# %%
sentences = gene_disease_abstract_map.stems.tolist()

# %%
import numpy as np

# %%
l = gene_disease_abstract_map.stems.values.flatten().tolist()
flat_l = [e for v in l for e in v]
print(flat_l)
# Out:
# ['background', ':', 'to', 'date', ',', 'small', 'portion', 'genet', 'variat', 'primari', 'open-angl', 'glaucoma', '(', 'poag', ')', ',', 'major', 'type', 'glaucoma', ',', 'elucid', '.', 'method', 'and', 'princip', 'find', ':', 'we', 'examin', 'two', 'data', 'set', 'genome-wid', 'associ', 'studi', '(', 'gwa', ')', 'deriv', 'total', '2,219', 'japanes', 'subject', '.', 'first', ',', 'perform', 'gwa', 'analyz', '653,519', 'autosom', 'common', 'single-nucleotid', 'polymorph', '(', 'snp', ')', '833', 'poag', 'patient', '686', 'control', '.', 'as', 'result', ',', 'five', 'variant', 'pass', 'bonferroni', 'correct', 'identifi', 'cdkn2b-as1', 'chromosom', '9p21.3', ',', 'alreadi', 'report', 'signific', 'locu', 'caucasian', 'popul', '.', 'moreov', ',', 'combin', 'data', 'set', 'previou', 'gwa', 'data', 'set', 'deriv', '411', 'poag', 'patient', '289', 'control', 'mantel-haenszel', 'test', ',', 'combin', 'variant', 'show', 'stronger', 'associ', 'poag', '(', 'p', '<', '5.8×10', '(', '−10', ')', ')', '.', 'we', 'subdivid', 'case', 'group', 'two', 'subtyp', 'base', 'valu', 'intraocular', 'pressur', '(', 'iop', ')', '—poag', 'high', 'iop', '(', 'high', 'pressur', 'glaucoma', ',', 'hpg', ')', 'normal', 'iop', '(', 'normal', 'pressur', 'glaucoma', ',', 'npg', ')', '—and', 'perform', 'gwa', 'use', 'two', 'data', 'set', ',', 'preval', 'npg', 'japanes', 'much', 'higher', 'caucasian', '.', 'the', 'result', 'suggest', 'variant', 'cdkn2b-as1', 'locu', 'like', 'signific', 'npg', 'patient', '.', 'conclus', 'and', 'signific', ':', 'in', 'studi', ',', 'success', 'identifi', 'poag-associ', 'variant', 'cdkn2b-as1', 'locu', 'use', 'japanes', 'popul', ',', 'i.e.', ',', 'variant', 'origin', 'report', 'associ', 'caucasian', 'popul', '.', 'although', 'not', 'rule', 'signific', 'could', 'due', 'differ', 'sampl', 'size', 'hpg', 'npg', ',', 'variant', 'could', 'associ', 'specif', 'vulner', 'optic', 'nerv', 'iop', ',', 'use', 'investig', 'etiolog', 'glaucoma', '.', 'long', 'non-cod', 'rna', '(', 'lncrna', ')', 'identifi', 'essenti', 'mediat', 'neurolog', 'dysfunct', '.', 'our', 'previou', 'studi', 'show', 'berberin', '(', 'bbr', ')', 'hamper', 'nuclear-to-cytosol', 'transloc', 'high-mobl', 'group', 'box', '1', '(', 'hmgb1', ')', 'process', 'poststrok', 'inflamm', '.', 'in', 'studi', ',', 'explor', 'role', 'lncrna', 'metastasis‐associ', 'lung', 'adenocarcinoma', 'transcript', '1', '(', 'malat1', ')', 'process', 'bbr-induc', 'inhibit', 'hmgb1', 'ischem', 'brain', '.', 'befor', '60-min', 'mcao', 'surgeri', ',', 'mice', 'pretreat', 'bbr', '(', '50', 'mg·', 'kg', '(', '−1', ')', 'per', 'day', ',', 'ig', ')', '14', 'day', 'icv', 'inject', 'specif', 'lentivir', 'vector', 'shrna', '.', 'we', 'show', 'mcao', 'caus', 'mark', 'increas', 'express', 'malat1', 'hmgb1', 'ipsilater', 'cortex', ',', 'significantli', 'attenu', 'pretreat', 'bbr', '.', 'knockdown', 'malat1', 'attenu', 'inflammatori', 'injuri', 'brain', 'ischemia', ',', 'wherea', 'overexpress', 'malat1', 'exacerb', 'ischem', 'brain', 'inflamm', '.', 'overexpress', 'malat1', 'also', 'revers', 'bbr-induc', 'reduct', 'hmgb1', 'proinflammatori', 'cytokin', '.', 'the', 'result', 'suggest', 'potenti', 'correl', 'malat1', 'stroke', 'inflamm', '.', 'base', 'informat', 'analysi', 'predict', 'hmgb1', 'direct', 'downstream', 'target', 'mir-181c-5p', ',', 'wherea', 'malat1', 'act', 'competit', 'endogen', 'rna', '(', 'cerna', ')', 'mir-181c-5p', 'target', '3′-utr', 'hmgb1', 'promot', 'inflamm', 'ischem', 'stroke', '.', 'knockdown', 'malat1', 'significantli', 'decreas', 'hmgb1', 'level', ',', 'could', 'abrog', 'transfect', 'mir-181c-5p', 'inhibitor', '.', 'taken', 'togeth', ',', 'result', 'demonstr', 'first', 'time', 'malat1/mir-181c-5p/hmgb1', 'axi', 'may', 'key', 'pathway', 'bbr-induc', 'antiinflamm', 'effect', 'stroke', ',', 'may', 'provid', 'novel', 'avenu', 'target', 'therapi', '.', 'background', ':', 'dengu', ',', 'chikungunya', 'zika', 'virus', '(', 'denv', ',', 'chikv', 'zikv', ')', 'transmit', 'sylvat', 'transmiss', 'cycl',  ...

# %%
w2v_model = Word2Vec(min_count=1, window=4, vector_size=300, sample=1e-5, alpha=0.03, min_alpha=0.0007, negative=20, workers=multiprocessing.cpu_count() - 1)

# %%
w2v_model.build_vocab(sentences, progress_per=50000)

# %%
w2v_model.train(sentences, total_examples=w2v_model.corpus_count, epochs=10, report_delay=1)
# Out:
# (129891, 668250)

# %%
w2v_model.init_sims(replace=True)
# Out:
# /tmp/ipykernel_3267854/514372312.py:1: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v_model.init_sims(replace=True)

# %%
w2v_model.save("word2vec_for_gene.model")

# %%
gene_disease_abstract_map.to_csv('gene_disease_abstract_map_with_stems.csv', index=False)

# %%
print('cdkn2b-as1' in flat_l)
# Out:
# True
